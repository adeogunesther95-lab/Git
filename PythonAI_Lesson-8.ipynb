# %% [markdown]
# <a href="https://colab.research.google.com/github/adeogunesther95-lab/Git/blob/main/PythonAI_Lesson-8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from rich import print
from rich.markdown import Markdown

api_key ="bf602aabco34t729377499af62121a7a"
prompt = "Please generate a well-formatted Carbonara recipe that is 10 lines or less. Please add a salutation and an emjoi at the end"
context = "You are a renowned chef, known for making the best Carbonara dish around the globe"
api_url =f"https://api.shecodes.io/ai/v1/generate?prompt={prompt}&context={context}&key={api_key}"

response = requests.get(api_url)
data = response.json()
markdown_text = Markdown(data['answer'])

print(markdown_text)
# Out:
#                                              Classic Carbonara Recipe
#
# Ingredients:
#
#  • 400g spaghetti
#  • 150g guanciale or pancetta, diced
#  • 3 large eggs
#  • 100g pecorino romano cheese, grated
#  • Freshly cracked black pepper
#  • Salt (for pasta water)
#
# Instructions:
#
#  1 Cook spaghetti in salted boiling water until al dente; reserve 1 cup of pasta water.
#  2 In a pan, sauté guanciale until crispy.
#  3 In a bowl, whisk eggs, cheese, and pepper.
#  4 Drain pasta and combine it with guanciale in the pan.
#  5 Remove from heat, and quickly mix in the egg mixture, adding reserved pasta water as needed.
#  6 Serve immediately, garnishing with additional cheese and pepper.
#
# Buon appetito! 🍝
