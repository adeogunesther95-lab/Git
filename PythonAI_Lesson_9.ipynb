# %% [markdown]
# <a href="https://colab.research.google.com/github/adeogunesther95-lab/Git/blob/main/PythonAI_Lesson_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from rich import print
import requests

api_key ="bf602aabco34t729377499af62121a7a"
prompt = "Please list five most popular Italian dish, with an accompanying emoji at the begining of each dish. Each dish should be separated by a semicolon"
context = "You are a popular Italian chef"
api_url = f"https://api.shecodes.io/ai/v1/generate?prompt={prompt}&context={context}&key={api_key}"

response = requests.get(api_url)
data = response.json()

print(data['answer'])
# Out:
# 🍝 Spaghetti Carbonara; 🍕 Margherita Pizza; 🍲 Risotto alla Milanese; 🍗 Osso Buco; 🍰 Tiramisu
