# %% [markdown]
# <a href="https://colab.research.google.com/github/adeogunesther95-lab/Git/blob/main/PythonAI_Wk-1_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from rich import print
from rich.markdown import Markdown
import requests

city = input("Please enter a city:" )
api_key = "bf602aabco34t729377499af62121a7a"
prompt = f"Please provide a list of the top 3 restaurants in {city}, with some background information on each provided restaurant and their popular dishes. "
context = "You are a fanous world traveller and food critique"
api_url = f"https://api.shecodes.io/ai/v1/generate?prompt={prompt}&context={context}&key={api_key}"

response = requests.get(api_url)
data = response.json()
markdown = Markdown(data['answer'])

print(markdown)
# Out:
# Please enter a city:Lagos
# Lagos, Nigeria, is renowned for its vibrant food scene, blending traditional Nigerian cuisine with international
# influences. Here are the top three restaurants in Lagos that are must-visit for anyone looking to experience the
# city’s culinary delights:
#
#                                                      1. Nkoyo
#
# Location: Onikan, Lagos
#
# Background: Nkoyo is a well-regarded restaurant situated near the waterfront, offering stunning views of the Lagos
# lagoon. It is named after a traditional Nigerian term that means "to find." The restaurant is known for its modern
# take on Nigerian and continental cuisine, creating a unique dining experience that incorporates local ingredients
# with international techniques.
#
# Popular Dishes:
#
#  • Jollof Rice: A staple of Nigerian cuisine, Nkoyo’s version features perfectly cooked rice infused with aromatic
#    spices and served with a side of fried plantains and assorted meats.
# ...
